# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip uninstall torchtext keras TensorFlow xformers chex optax dopamine-rl flax -y
#!pip install torch==1.13.1+cu116 torchvision==0.14.1+cu116 torchaudio==0.13.1 torchdata==0.5.1  --extra-index-url https://download.pytorch.org/whl/cu116
# !pip install numpy==1.23.4
# Out:
# Found existing installation: torchtext 0.16.0
# Uninstalling torchtext-0.16.0:
#   Successfully uninstalled torchtext-0.16.0
# Found existing installation: keras 2.15.0
# Uninstalling keras-2.15.0:
#   Successfully uninstalled keras-2.15.0
# Found existing installation: tensorflow 2.15.0
# Uninstalling tensorflow-2.15.0:
#   Successfully uninstalled tensorflow-2.15.0
# WARNING: Skipping xformers as it is not installed.
# Found existing installation: chex 0.1.85
# Uninstalling chex-0.1.85:
#   Successfully uninstalled chex-0.1.85
# Found existing installation: optax 0.1.9
# Uninstalling optax-0.1.9:
#   Successfully uninstalled optax-0.1.9
# Found existing installation: dopamine-rl 4.0.6
# Uninstalling dopamine-rl-4.0.6:
#   Successfully uninstalled dopamine-rl-4.0.6
# Found existing installation: flax 0.8.1
# Uninstalling flax-0.8.1:
#   Successfully uninstalled flax-0.8.1
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 40.7 MB/s eta 0:00:00
# ...

# %%
# %cd /content/drive/MyDrive/ODISE-main
# Out:
# /content/drive/MyDrive/ODISE-main

# %%
# !pip install -e .
# Out:
# Obtaining file:///content/drive/MyDrive/ODISE-main
#   Preparing metadata (setup.py) ... done
# Processing //content/drive/MyDrive/ODISE-main/third_party/Mask2Former (from odise==0.1)
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached https://github.com/facebookresearch/detectron2/archive/v0.6.zip
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached https://github.com/cocodataset/panopticapi/archive/master.zip
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached https://github.com/lvis-dataset/lvis-api/archive/master.zip
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for mask2former: filename=mask2former-0.1-cp310-cp310-linux_x86_64.whl size=2938317 sha256=d5039c1279dacdc9072444890113c77fb589be1663b8c959f73cf64eb8316c0a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-9u2xh0lh/wheels/1f/d1/6f/097816a93a9abfc67d7d2015e462e15888b3b39c54243760ed
# Successfully built mask2former
# ...
#   Attempting uninstall: mask2former
# ...

# %%
# %cd /content/drive/MyDrive/ODISE-main
# Out:
# /content/drive/MyDrive/ODISE-main

# %%
# !python demo/demo.py \
 --input demo/examples/coco.jpg \
 --output demo/coco_pred.jpg \
 --vocab "black pickup truck, pickup truck; blue sky, sky"
# Out:
# No module 'xformers'. Proceeding without it.
# [02/26 07:08:15 odise]: extra classes: [['black pickup truck', 'pickup truck'], ['blue sky', 'sky']]
# [02/26 07:08:16 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(1024, 1024), max_size=2560, sample_style='choice')]
# v1-inference.yaml: 8.19kB [00:00, 126kB/s]
# LatentDiffusion: Running in eps-prediction mode
# DiffusionWrapper has 859.52 M params.
# making attention of type 'vanilla' with 512 in_channels
# Working with z of shape (1, 4, 32, 32) = 4096 dimensions.
# making attention of type 'vanilla' with 512 in_channels
# vocab.json: 100% 961k/961k [00:00<00:00, 10.2MB/s]
# merges.txt: 100% 525k/525k [00:00<00:00, 6.63MB/s]
# special_tokens_map.json: 100% 389/389 [00:00<00:00, 2.22MB/s]
# tokenizer_config.json: 100% 905/905 [00:00<00:00, 5.49MB/s]
# config.json: 100% 4.52k/4.52k [00:00<00:00, 20.2MB/s]
# model.safetensors: 100% 1.71G/1.71G [00:19<00:00, 88.8MB/s]
# ...

# %%
# !python demo/demo.py \
  --input demo/examples/ego4d.jpg \
  --output demo/ego4d_pred1.jpg \
  --label "" --vocab "boy,soap,flover,spray" \
# Out:
# No module 'xformers'. Proceeding without it.
# [02/26 08:29:27 odise]: extra classes: [['boy', 'soap', 'flover', 'spray']]
# [02/26 08:29:27 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(1024, 1024), max_size=2560, sample_style='choice')]
# LatentDiffusion: Running in eps-prediction mode
# DiffusionWrapper has 859.52 M params.
# making attention of type 'vanilla' with 512 in_channels
# Working with z of shape (1, 4, 32, 32) = 4096 dimensions.
# making attention of type 'vanilla' with 512 in_channels
# The checkpoint state_dict contains keys that are not used by the model:
#   model_ema.{decay, num_updates}
# [02/26 08:30:32 odise.modeling.backbone.feature_extractor]: backbone_in_size: (512, 512), slide_training: True,
# slide_inference: True,
# min_stride: 4, max_stride: 32,
# projection_dim: 512,
# out_feature_channels: {'s2': 512, 's3': 512, 's4': 512, 's5': 512}
# ...
